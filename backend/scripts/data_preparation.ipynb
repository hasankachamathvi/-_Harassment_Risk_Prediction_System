# %% [markdown]
# # Data Preparation

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import joblib
import os

# %%
fp = pd.read_csv("../data/women_risk.csv")

# %%
fp.head()
# Out:
#              Timestamp 1. What is your age group? 2. What is your occupation?  \
# 0  2026-01-29 22:19:51                      18-25                     Student
# 1  2026-01-29 22:20:52                      18-25                     Student
# 2  2026-01-29 23:27:42                      18-25                     Student
# 3  2026-01-30 20:28:06                      18-25                     Student
# 4  2026-01-30 22:06:27                      26-35               Self-employed
#
#   3. At what time of day did the incident occur?  \
# 0                                        Evening
# 1                                        Evening
# 2                                          Night
# 3                                          Night
# 4                                  Early Morning
#
#   4. Where did the incident occur?  \
# 0              Street/Public place
# 1                 Public transport
# 2                  Online platform
# 3                 Public transport
# 4              Street/Public place
#
#   5. How crowded was the location at the time of the incident?  \
# 0                  The location was slightly crowded
# 1                 The location was extremely crowded
# 2                The location was not crowded at all
# 3                 The location was extremely crowded
# 4                    The location was mostly crowded
#
#   6. What was the lighting condition in the area?  \
# 0                       The lighting was moderate
# 1                           The lighting was poor
# 2                      The lighting was very poor
# 3                           The lighting was poor
# 4                       The lighting was moderate
#
#   7. Was any form of security present at the location?  \
# 0                       There was no security at all
# 1                       There was no security at all
# 2                       There was no security at all
# 3                       There was no security at all
# 4                            There was some security
#
#   8. Were you familiar with the area where the incident occurred?  \
# 0                             I mostly knew the area
# 1                           I somewhat knew the area
# 2                     I did not know the area at all
# 3                             I mostly knew the area
# 4                         I knew the area completely
#
#       9. What type of harassment did you experience?  \
# 0  Physical harassment (touching, grabbing, assault)
# 1  Physical harassment (touching, grabbing, assault)
# 2  Online harassment (messages, social media, calls)
# 3  Physical harassment (touching, grabbing, assault)
# 4     Verbal harassment (unwanted comments, remarks)
#
#   10. How often have you experienced harassment in similar situations?  \
# 0  I have sometimes experienced harassment in sim...
# 1  I have never experienced harassment in similar...
# 2  I have sometimes experienced harassment in sim...
# 3  I have rarely experienced harassment in simila...
# 4  I have sometimes experienced harassment in sim...
#
#   11. How safe did you feel during the incident?  \
# 0                           I felt somewhat safe
# 1                     Option I felt very unsafe1
# 2                             I felt very unsafe
# 3                             I felt very unsafe
# 4                             I felt very unsafe
#
#   12. Overall, how would you rate the risk level of harassment in that situation?
# 0             There was no risk of harassment at all
# 1           There was a very high risk of harassment
# 2           There was a very high risk of harassment
# 3                There was a high risk of harassment
# 4                There was a high risk of harassment

# %%
fp.shape
# Out:
# (115, 13)

# %%
fp.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 13 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   Timestamp                                                                        115 non-null    str
#  1   1. What is your age group?                                                       115 non-null    str
#  2   2. What is your occupation?                                                      115 non-null    str
#  3   3. At what time of day did the incident occur?                                   115 non-null    str
#  4   4. Where did the incident occur?                                                 115 non-null    str
#  5   5. How crowded was the location at the time of the incident?                     115 non-null    str
#  6   6. What was the lighting condition in the area?                                  115 non-null    str
#  7   7. Was any form of security present at the location?                             115 non-null    str
#  8   8. Were you familiar with the area where the incident occurred?                  115 non-null    str
#  9   9. What type of harassment did you experience?                                   115 non-null    str
#  10  10. How often have you experienced harassment in similar situations?             115 non-null    str
#  11  11. How safe did you feel during the incident?                                   115 non-null    str
#  12  12. Overall, how would you rate the risk level of harassment in that situation?  115 non-null    str
# dtypes: str(13)
# memory usage: 11.8 KB

# %%
fp.isnull().sum()
# Out:
# Timestamp                                                                          0
# 1. What is your age group?                                                         0
# 2. What is your occupation?                                                        0
# 3. At what time of day did the incident occur?                                     0
# 4. Where did the incident occur?                                                   0
# 5. How crowded was the location at the time of the incident?                       0
# 6. What was the lighting condition in the area?                                    0
# 7. Was any form of security present at the location?                               0
# 8. Were you familiar with the area where the incident occurred?                    0
# 9. What type of harassment did you experience?                                     0
# 10. How often have you experienced harassment in similar situations?               0
# 11. How safe did you feel during the incident?                                     0
# 12. Overall, how would you rate the risk level of harassment in that situation?    0
# dtype: int64

# %%
fp = fp.dropna()

# %%
fp.shape
# Out:
# (115, 13)

# %%
fp = fp.drop_duplicates()

# %%
fp.shape
# Out:
# (115, 13)

# %%
categorical_cols = fp.select_dtypes(include=['object']).columns.tolist()
categorical_cols
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_4000\3239708821.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_cols = fp.select_dtypes(include=['object']).columns.tolist()
# ['Timestamp',
#  '1. What is your age group?',
#  '2. What is your occupation?',
#  '3. At what time of day did the incident occur?',
#  '4. Where did the incident occur?',
#  '5. How crowded was the location at the time of the incident?',
#  '6. What was the lighting condition in the area?',
#  '7. Was any form of security present at the location?',
#  '8. Were you familiar with the area where the incident occurred?',
#  '9. What type of harassment did you experience?',
#  '10. How often have you experienced harassment in similar situations?',
#  '11. How safe did you feel during the incident?',
#  '12. Overall, how would you rate the risk level of harassment in that situation?']

# %%
label_encoders = {}

for col in categorical_cols:
    le = LabelEncoder()
    fp[col] = le.fit_transform(fp[col])
    label_encoders[col] = le

# %%
fp.head()
# Out:
#    Timestamp  1. What is your age group?  2. What is your occupation?  \
# 0          0                           0                            3
# 1          1                           0                            3
# 2          2                           0                            3
# 3          3                           0                            3
# 4          4                           1                            2
#
#    3. At what time of day did the incident occur?  \
# 0                                               2
# 1                                               2
# 2                                               4
# 3                                               4
# 4                                               1
#
#    4. Where did the incident occur?  \
# 0                                 3
# 1                                 2
# 2                                 1
# 3                                 2
# 4                                 3
#
#    5. How crowded was the location at the time of the incident?  \
# 0                                                  4
# 1                                                  0
# 2                                                  3
# 3                                                  0
# 4                                                  2
#
#    6. What was the lighting condition in the area?  \
# 0                                                2
# 1                                                3
# 2                                                4
# 3                                                3
# 4                                                2
#
#    7. Was any form of security present at the location?  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  3
#
#    8. Were you familiar with the area where the incident occurred?  \
# 0                                                  3
# 1                                                  4
# 2                                                  1
# 3                                                  3
# 4                                                  2
#
#    9. What type of harassment did you experience?  \
# 0                                               2
# 1                                               2
# 2                                               1
# 3                                               2
# 4                                               4
#
#    10. How often have you experienced harassment in similar situations?  \
# 0                                                  3
# 1                                                  0
# 2                                                  3
# 3                                                  2
# 4                                                  3
#
#    11. How safe did you feel during the incident?  \
# 0                                               2
# 1                                               5
# 2                                               4
# 3                                               4
# 4                                               4
#
#    12. Overall, how would you rate the risk level of harassment in that situation?
# 0                                                  4
# 1                                                  3
# 2                                                  3
# 3                                                  0
# 4                                                  0

# %%
os.makedirs('../models', exist_ok=True)
joblib.dump(label_encoders, '../models/label_encoders.pkl')
# Out:
# ['../models/label_encoders.pkl']

# %%
fp.to_csv("../data/women_risk_cleaned.csv", index=False)

# %%
fp.shape
# Out:
# (115, 13)
